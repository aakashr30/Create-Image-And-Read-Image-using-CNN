# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashr30/Create-Image-And-Read-Image-using-CNN/blob/main/Create_And_Data_Image%5BCNN%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# %%
#create the image and read the image
myimage = Image.ImageTranformHandler = Image.open('/content/drive/MyDrive/0 (1).MKCE/15.CV/Sample images/Nayanthara.jpg')
myimage
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=356x435 at 0x7FBB1C3F0350>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,8))
plt.imshow(myimage)

# %%
pix_val = list(myimage.getdata())

# %%
pix_val
# Out:
# [(255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
#  (255, 255, 255),
# ...

# %%
#Then the command to flattern the list is:
pix_val_flat = [x for sets in pix_val for x in sets]
pix_val_flat
# Out:
# [255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
#  255,
# ...

# %%
#bw2color_myimage.py
myimage.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=356x435 at 0x7F262D716E50>

# %%
z = myimage.convert('1')
z
# Out:
# <PIL.Image.Image image mode=1 size=356x435 at 0x7F262D71CC50>

# %%
myimage.convert('LA')
# Out:
# <PIL.Image.Image image mode=LA size=356x435 at 0x7F262D720110>

# %%
myimage.info
# Out:
# {'dpi': (72, 72),
# ...

# %%
#Find thhe originasize of image
print("\n original value: %r \n\n" % z)
# Out:
#  original value: <PIL.Image.Image image mode=1 size=356x435 at 0x7F262D71CC50>

# %%
#convert the image to matrix with value from 0 to 255
arr = np.asarray(z)
arr
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True, False,  True, ...,  True, False,  True],
#        [False,  True, False, ..., False,  True, False],
#        [ True, False,  True, ...,  True, False,  True]])

# %%
# import the necessary packages
import numpy as np
import argparse
import cv2
# construct the argument parser and parse the arguments
ap = argparse.ArgumentParser()
ap.add_argument("-i", "--image", type=str, required=True,
	help="path to input black and white image")
ap.add_argument("-p", "--prototxt", type=str, required=True,
	help="path to Caffe prototxt file")
ap.add_argument("-m", "--model", type=str, required=True,
	help="path to Caffe pre-trained model")
ap.add_argument("-c", "--points", type=str, required=True,
	help="path to cluster center points")
args = vars(ap.parse_args())
# Out:
# usage: ipykernel_launcher.py [-h] -i IMAGE -p PROTOTXT -m MODEL -c POINTS
# ipykernel_launcher.py: error: the following arguments are required: -i/--image, -p/--prototxt, -m/--model, -c/--points
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
